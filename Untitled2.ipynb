# %%
# Importar las bibliotecas necesarias
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, clear_output, HTML

# Lista de personajes
characters = [
        {"name": "Shrek", "description": "Protagonista, un ogro verde que vive en un pantano."},
    {"name": "Burro (Donkey)", "description": "Amigo parlanchín de Shrek, que lo acompaña en sus aventuras."},
    {"name": "Princesa Fiona", "description": "Esposa de Shrek, quien se transforma en ogresa."},
    {"name": "Dragona", "description": "Dragón hembra que se enamora de Burro."},
    {"name": "Gato con Botas", "description": "Gato espadachín que se une a Shrek."},
    {"name": "Lord Farquaad", "description": "Villano del primer “Shrek”, busca casarse con Fiona para ser rey."},
    {"name": "Príncipe Encantador", "description": "Villano en “Shrek 2”, hijo del Hada Madrina."},
    {"name": "Hada Madrina", "description": "Villana mágica de “Shrek 2”."},
    {"name": "Rey Harold", "description": "Padre de Fiona, rey de Muy Muy Lejano."},
    {"name": "Reina Lillian", "description": "Madre de Fiona, reina de Muy Muy Lejano."},
    {"name": "Rey Arturo (Artie)", "description": "Primo de Fiona, que Shrek busca en “Shrek Tercero”."},
    {"name": "Merlín", "description": "Mago excéntrico en “Shrek Tercero”."},
    {"name": "Big Bad Wolf", "description": "Lobo Feroz, amigo de Shrek."},
    {"name": "Los Tres Cerditos", "description": "Amigos de Shrek."},
    {"name": "Los Tres Ratones Ciegos", "description": "Pequeños ratones amigos de Shrek."},
    {"name": "Gingy (Hombre de Jengibre)", "description": "Personaje de galleta de jengibre, amigo de Shrek."},
    {"name": "Pinocchio (Pinocho)", "description": "Personaje de cuento, amigo de Shrek."},
    {"name": "Los Enanitos de Blancanieves", "description": "Amigos de Shrek."},
    {"name": "Espejo Mágico", "description": "Espejo que ofrece información y consejos."},
    {"name": "Big Jack Horner", "description": "Villano en ‘El Gato con Botas: El último deseo’."},
    {"name": "Perrito", "description": "Personaje en ‘El Gato con Botas: El último deseo’."},
    {"name": "Muerte", "description": "Villano en ‘El Gato con Botas: El último deseo’."},
    {"name": "Jack y Jill", "description": "Villanos en ‘El Gato con Botas’."},
    {"name": "Rapunzel", "description": "Princesa en “Shrek Tercero”."},
    {"name": "Cenicienta", "description": "Princesa en “Shrek Tercero”."},
    {"name": "Blanca Nieves", "description": "Princesa en “Shrek Tercero”."},
    {"name": "Bella Durmiente", "description": "Princesa en “Shrek Tercero”."},
    {"name": "Princesa Cisne", "description": "Mencionada brevemente."},
    {"name": "Princesa Merlina", "description": "Mencionada en la saga."},
    {"name": "Princesa Chicle", "description": "Mencionada en “Shrek Tercero”."},
    {"name": "Princesa Caperucita Roja", "description": "Parte del elenco de cuentos de hadas en “Shrek Tercero”."},
    {"name": "Princesa Melina", "description": "Mencionada en la saga."},
    {"name": "Reina", "description": "Personaje en “Shrek 2”."},
    {"name": "Rey", "description": "Personaje en “Shrek 2”."},
    {"name": "Príncipe", "description": "Personaje en “Shrek Tercero”."},
    {"name": "Rumpelstiltskin", "description": "Villano en “Shrek para siempre”."},
    {"name": "Los Ogres", "description": "Grupo de ogros en “Shrek para siempre”."},
    {"name": "El Flautista de Hamelín", "description": "Personaje que usa una flauta mágica."},
    {"name": "Capitán Garfio", "description": "Personaje de cuento."},
    {"name": "El Lobo Feroz", "description": "Personaje recurrente."},
    {"name": "Los Tres Cerdos", "description": "Amigos de Shrek."},
    {"name": "Reina Malvada", "description": "Villana."},
    {"name": "Feliz", "description": "Enano."},
    {"name": "Dormilón", "description": "Enano."},
    {"name": "Tímido", "description": "Enano."},
    {"name": "Gruñón", "description": "Enano."},
    {"name": "Mocoso", "description": "Enano."},
    {"name": "Tontín", "description": "Enano."},
    {"name": "Rompehuesos", "description": "Personaje secundario."},
    {"name": "El Gato con Botas", "description": "Secundario importante."},
    {"name": "Robin Hood", "description": "Personaje en “Shrek”."},
    {"name": "Dama Marian", "description": "Personaje en “Shrek”."},
    {"name": "La Cenicienta", "description": "Secundario en “Shrek Tercero”."},
    {"name": "Fiona", "description": "Protagonista femenina."},
    {"name": "Burro", "description": "Compañero fiel de Shrek."},
    {"name": "Gato con Botas", "description": "Personaje de “El Gato con Botas”."},
    {"name": "Los Tres Osos", "description": "Secundarios en la saga."},
    {"name": "Los Ositos", "description": "Amigos de Shrek."},
    {"name": "El Panadero de Gingerbread", "description": "Secundario."},
    {"name": "El Enano de Rumpelstiltskin", "description": "Villano."},
    {"name": "El Hada Azul", "description": "Secundario mágico."},
    {"name": "El Ratón Ciego", "description": "Amigo de Shrek."},
    {"name": "La Princesa", "description": "Mencionada."},
    {"name": "El Rey León", "description": "Mencionado."},
    {"name": "El Jorobado de Notre Dame", "description": "Personaje de cuento."},
    {"name": "La Bella y la Bestia", "description": "Mencionados."},
    {"name": "Pinocho", "description": "Secundario recurrente."},
    {"name": "El Hombre de Jengibre", "description": "Personaje recurrente."}
]

# Variable para almacenar las selecciones de los usuarios
selected_characters = []

# Función para actualizar el menú desplegable de personajes
def update_character_dropdown():
    available_characters = [char['name'] for char in characters if char['name'] not in [sel['character'] for sel in selected_characters]]
    character_dropdown.options = available_characters

# Función para mostrar la descripción de un personaje
def show_character_description(change):
    with description_output:
        clear_output()
        selected_character = change['new']
        character_info = next((char for char in characters if char['name'] == selected_character), None)
        if character_info:
            print(f"Descripción de {selected_character}: {character_info['description']}")

# Widget de selección de personajes
character_dropdown = widgets.Dropdown(
    options=[char['name'] for char in characters],
    description='Personaje:'
)

# Widget para el nombre del usuario
name_text = widgets.Text(
    placeholder='Tu nombre',
    description='Nombre:'
)

# Botón para confirmar la selección
select_button = widgets.Button(description='Seleccionar', button_style='success')
confirm_button = widgets.Button(description='Terminar', button_style='danger', layout=widgets.Layout(margin='20px 0 0 0', background_color='#ff00ff'))
admin_button = widgets.Button(description='Administrador', button_style='info')

# Área de salida para mostrar información y mensajes
output = widgets.Output()
description_output = widgets.Output()
notification_output = widgets.Output()
admin_output = widgets.Output()
change_output = widgets.Output()

# Función para mostrar la lista de personajes seleccionados
def show_selected_characters():
    with output:
        clear_output()
        if selected_characters:
            df = pd.DataFrame(selected_characters)
            display(HTML(df.to_html(index=False)))
        else:
            print("Ningún personaje ha sido seleccionado aún.")

# Función para seleccionar un personaje
def select_character(b):
    with notification_output:
        clear_output()
        name = name_text.value
        character = character_dropdown.value
        if name and character:
            if character not in [sel['character'] for sel in selected_characters]:
                selected_characters.append({"name": name, "character": character})
                update_character_dropdown()
                print(f"{name} ha seleccionado a {character}.")
                show_selected_characters()
                change_character_area()
            else:
                print(f"El personaje {character} ya ha sido seleccionado. Por favor, elige otro.")
        else:
            print("Por favor, completa tu nombre y selecciona un personaje.")
        name_text.value = ""

# Función para confirmar la selección
def confirm_selection(b):
    with notification_output:
        clear_output()
        print("¡Ya eres un personaje de la FIESTA SHREK! Te esperamos.")

# Función para entrar al área de administración
def admin_area(b):
    with admin_output:
        clear_output()
        password_text = widgets.Password(
            placeholder='Contraseña',
            description='Contraseña:'
        )
        login_button = widgets.Button(description='Entrar', button_style='info')
        error_output = widgets.Output()

        def admin_login(b):
            password = password_text.value
            with error_output:
                clear_output()
                if password == '7777':
                    show_admin_panel()
                else:
                    print("Contraseña incorrecta.")

        login_button.on_click(admin_login)
        display(widgets.VBox([password_text, login_button, error_output]))

# Función para mostrar el panel de administración
def show_admin_panel():
    with admin_output:
        clear_output()
        home_button = widgets.Button(description='Home', button_style='info')

        def go_home(b):
            with admin_output:
                clear_output()
                display(main_interface)

        home_button.on_click(go_home)

        if selected_characters:
            buttons_container = []
            for sel in selected_characters:
                name = sel['name']
                character = sel['character']
                delete_button = widgets.Button(description='Eliminar', button_style='danger', icon='trash', layout=widgets.Layout(width='100px'))
                delete_button.on_click(lambda b, name=name: admin_remove_selection(name))
                buttons_container.append(widgets.HBox([widgets.Label(f"{name} - {character}"), delete_button]))
            display(widgets.VBox(buttons_container))
            display(home_button)
        else:
            print("No hay personajes seleccionados.")
            display(home_button)

# Función para eliminar una selección en el panel de administración
def admin_remove_selection(name):
    global selected_characters
    selected_characters = [sel for sel in selected_characters if sel['name'] != name]
    update_character_dropdown()
    show_admin_panel()
    show_selected_characters()

# Función para cambiar un personaje
def change_character_area():
    with change_output:
        clear_output()
        if selected_characters:
            name_dropdown = widgets.Dropdown(
                options=[sel['name'] for sel in selected_characters],
                description='Nombre:'
            )
            new_character_dropdown = widgets.Dropdown(
                options=[char['name'] for char in characters],
                description='Nuevo Personaje:'
            )
            change_button = widgets.Button(description='Cambiar', button_style='warning')
            change_notification = widgets.Output()

            def change_character_action(b):
                selected_name = name_dropdown.value
                new_character = new_character_dropdown.value
                with change_notification:
                    clear_output()
                    if new_character not in [sel['character'] for sel in selected_characters]:
                        for sel in selected_characters:
                            if sel['name'] == selected_name:
                                sel['character'] = new_character
                                break
                        update_character_dropdown()
                        show_selected_characters()
                        print(f"{selected_name} ha cambiado a {new_character}.")
                    else:
                        print(f"El personaje {new_character} ya ha sido seleccionado. Por favor, elige otro.")

            change_button.on_click(change_character_action)
            display(widgets.VBox([name_dropdown, new_character_dropdown, change_button, change_notification]))
        else:
            print("No hay personajes seleccionados.")

# Conectar los botones y el dropdown con las funciones
character_dropdown.observe(show_character_description, names='value')
select_button.on_click(select_character)
confirm_button.on_click(confirm_selection)
admin_button.on_click(admin_area)

# Área de salida para la administración
admin_output = widgets.Output()

# Crear la interfaz principal
main_interface = widgets.VBox([
    widgets.HTML("<h2 style='text-align:center;'>FIESTA SHREK</h2>"),
    widgets.HTML("<h3>Descubre tu personaje</h3>"),
    character_dropdown,
    description_output,
    widgets.HTML("<h3>Selecciona tu personaje</h3>"),
    name_text,
    select_button,
    widgets.HTML("<h3>Personajes seleccionados</h3>"),
    output,
    widgets.HTML("<h3>Cambio de personaje</h3>"),
    change_output,
    confirm_button,
    admin_button,
    notification_output
])

# Mostrar la interfaz principal
display(main_interface)

# Mostrar la lista inicial de personajes seleccionados
show_selected_characters()
display(admin_output)
# Out:
# ...
# Output()
